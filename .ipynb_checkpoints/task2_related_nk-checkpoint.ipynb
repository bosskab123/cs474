# %%
import pandas as pd
import numpy as np
import os
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
import string
import random
import unicodedata
from string import punctuation
from string import digits
from nltk.stem import WordNetLemmatizer
import joblib

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import silhouette_score
from sklearn.decomposition import LatentDirichletAllocation

from tqdm import tqdm

import spacy
from spacy.matcher import Matcher
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Modern\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Modern\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
pd.set_option('max_colwidth',200)
### Reading data
data_dir = 'data/'
filename_prefix = 'koreaherald_1517_'
df = []

for i in range(8):
    df.append(pd.read_json(os.path.join(data_dir, filename_prefix + str(i) + '.json')))
df = pd.concat(df)
df.reset_index(inplace=True)
df = df.rename(columns=dict(zip(df.columns,[df.columns[i].strip() for i in range(len(df.columns))])))
df.drop('index', inplace=True, axis=1)

df['agg_title_body'] = df['title'] + df['body']

df.shape
# Out:
# (23769, 7)

# %%
nlp = spacy.load('en_core_web_lg')

# %%
### Lemmatization tool
stemmer = WordNetLemmatizer()
### Change similar words to the same word
UN_WORD = "The United Nations"
US_WORD = "The United States"
NK_WORD = "North Korea"
SK_WORD = "South Korea"

similar_words = {
    # Change to "The United States"
    "U.S.": US_WORD,
    "US": US_WORD,
    "USA": US_WORD,
    "United States": US_WORD,
    "United States'": US_WORD,
    "The United States'": US_WORD,
    
    # Change to "North Korea"
    "NK": NK_WORD,
    "NK's": NK_WORD,
    "N. Korea": NK_WORD,
    "N. Korea's": NK_WORD,
    "North Korea's": NK_WORD,
    
    # Change to "South Korea"
    "SK": SK_WORD,
    "SK's": SK_WORD,
    "S. Korea": SK_WORD,
    "S. Korea's": SK_WORD,
    "South Korea's": SK_WORD,
    
    # Change to "The United Nations"
    "United Nations": UN_WORD,
    "United Nations'": UN_WORD,
    "The United Nations'": UN_WORD,
    "UN": UN_WORD,
}

### Transform function
def text_cleaning(s: str):
        
    def replace_strange_char(s: str):
        non_en_chars = {
            "’": "'",
            "‘": "'"
        }

        def remove_non_en_chars(txt):
            # remove non english characters
            txt = convert_latin_chars(txt)
            for char in non_en_chars.keys():
                txt = re.sub(char, non_en_chars[char], txt)
            txt = re.sub(r'[^\x00-\x7F]+', ' ', txt)
            return txt

        def convert_latin_chars(txt):
            # convert latin characters
            return ''.join(char for char in unicodedata.normalize('NFKD', txt) if unicodedata.category(char) != 'Mn')

        s = remove_non_en_chars(s)
        s = convert_latin_chars(s)
        return s
    s = replace_strange_char(s)
    for key,value in similar_words.items():
        s = re.sub(key, value, s)
    return s

def spacy_tokenizer(s: str):
    # Change similar terms to the same term
    new_str = text_cleaning(s)
    doc = nlp(new_str)
    # Group tokens
    matcher = Matcher(nlp.vocab)
    token_groupup_pattern = [
        [{"LOWER": "the"}, {"LOWER": "united"}, {"LOWER": "nations"}],
        [{"LOWER": "the"}, {"LOWER": "united"}, {"LOWER": "states"}],
        [{"LOWER": "north"}, {"LOWER": "korea"}],
        [{"LOWER": "south"}, {"LOWER": "korea"}],
    ]
    matcher.add("TermGroup",token_groupup_pattern)
    matches = matcher(doc)
    merge_doc = []
    for nid, start, end in matches:
        merge_doc.append((start,end))
    with doc.retokenize() as retokenizer:
        for i in range(len(merge_doc)-1,-1,-1):
            retokenizer.merge(doc[merge_doc[i][0]:merge_doc[i][1]])
        
    # Remove all stopword, punctuation, number
    tokens = [ token.lemma_.lower() for token in doc \
              if not token.is_stop and not token.is_punct and not token.like_num and token.lemma_.strip()!= '']
    return tokens

# %%
def print_top_words(model, vectorizer, n_top_words):
    feature_names = vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        message = "\nTopic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
def most_related_docs(df, doc_topic_dist, topic_index, num_docs=5):
    sorted_doc = doc_topic_dist.sort_values(by=['{}'.format(topic_index)], ascending=False)
    return df.iloc[sorted_doc[:num_docs].index]

# %%
df_nk = df[df['section'] == 'North Korea']

# %%
# # Find all doc contains "North Korea"
# nk_vectorizer = CountVectorizer(tokenizer=spacy_tokenizer)
# nk_data_vectorized = nk_vectorizer.fit_transform(df_nk['agg_title_body'])
# joblib.dump(nk_vectorizer, 'data/nk_vectorizer.csv')
# joblib.dump(nk_data_vectorized, 'data/nk_data_vectorized.csv')

# %%
nk_vectorizer = joblib.load('data/nk_vectorizer.csv')
nk_data_vectorized = joblib.load('data/nk_data_vectorized.csv')

# %%
nk_lda_components = 50
# nk_lda = LatentDirichletAllocation(n_components=nk_lda_components, random_state=0)
# nk_lda.fit(nk_data_vectorized)
# joblib.dump(nk_lda, 'data/nk_{}lda.csv'.format(nk_lda_components))

# %%
nk_lda = joblib.load('data/nk_{}lda.csv'.format(nk_lda_components))

# %%
print_top_words(nk_lda, nk_vectorizer, n_top_words=25)
# Out:
# Topic #0: north korean defector south say ministry south korea koreans seoul year unification restaurant government country percent defect number official korea worker north korea accord defection minister come
#
# Topic #1: military korean say north south korea drill korea south north korea exercise joint seoul defense official provocation war attack ministry pyongyang u.s nuclear plan tension strike carry
#
# Topic #2: ` north korea talk nuclear say hwang envoy launch hold korean party north pyongyang japan beijing rocket china south korea u.s wu korea resume late kook counterpart
#
# Topic #3: f-35 europe asylum request european b-1bs vigilant practice statement.the interoperability ace refuge statistic contribute yonhap)among grant herim@heraldcorp.com rim sweden rejected.by dropsthe strict luxembourg eurostat bulgaria
#
# Topic #4: russia russian moscow kim visit north korea world attend putin say ceremony leader diplomatic tie president invite war invitation china youth foreign vladimir korean economic ii
#
# Topic #5: submarine slbm test missile launch north say ballistic underwater north korea conduct develop ton korea class water development capability u.s ship report sinpo sea ejection carry
#
# Topic #6: say defense south korea missile thaad system korean seoul north korea deployment north china korea u.s south peninsula high terminal military deploy threat area altitude decision nuclear
#
# Topic #7: citizen department ahn americans north korea american opposition travel lawmaker state kim act u.s rep poll crime minjoo warning consider saenuri law detain say detention pyongyang
#
# Topic #8: korean north complex south say industrial government park ministry north korea kaesong seoul factory unification firm inter wage official korea worker decision joint border pyongyang gaeseong
#
# Topic #9: percent public survey year show activity inspection military world $ total period hospital report rank health relate accord appearance datum quarter kim state average doctor
#
# Topic #10: trump say north korea china president nuclear chinese north donald think weapon administration xi go missile regime deal problem beijing war option the united states pressure house good
#
# Topic #11: say ship vessel carter nis afp transfer oil sony kong agency time hong video film official authority taiwanese un service lighthouse intelligence home studio office
#
# Topic #12: missile launch say test ballistic north range north korea fire korea nuclear rocket military pyongyang icbm long new kilometer intercontinental technology korean fly warhead kim claim
#
# Topic #39: nuclear test bomb north weapon say hydrogen claim north korea conduct korea expert h nuke report agency earthquake develop site institute warhead yield device material powerful
#
# Topic #40: video say ji pilot appear huong kim life tank flight show young leader hanoi tv away lee lim outlet vietnam return feature drama check wan
#
# Topic #41: football gram match aisyah sport cup player ration food recommend team recommendation court daily vx person drug woman confederation testify page year win friendly club
#
# Topic #42: kim jong say north korean nam un leader malaysia north korea police brother half suspect death kill woman attack agent airport murder malaysian late report assassination
#
# Topic #43: north north korea say u.s u.n korean pyongyang visit ban peace game sport pyeongchang winter olympic treaty south korea olympics talk world official yonhap hold nuclear general
#
# Topic #44: trump say north korea north korean military un korea nuclear war president threaten pyongyang donald missile guam kim washington threat fire leader jong action rhetoric ballistic
#
# Topic #45: north satellite test site say kim rocket pyongyang nuclear korean visit activity imagery ri lee show launch conduct long anniversary korea official facility leader tunnel
#
# Topic #46: trade china oil north korea economic sanction north year nuclear say pyongyang korea congress supply crude beijing import economy country power day chinese international test export
#
# Topic #47: say north north korea korean warmbier release year detain student american pyongyang korea state u.s citizen south travel month sentence home arrest otto country koreans official
#
# Topic #48: ri meeting korean foreign minister north say un official state kim yong new meet ministry kang general visit attend assembly choe director news hold country
#
# Topic #49: nuclear test north korea north sanction u.n security china council say resolution u.s rocket conduct ministry south korea long strong korean korea international foreign pyongyang range launch

# %%
# nk_doc_topic_dist = pd.DataFrame(nk_lda.transform(nk_data_vectorized))
# nk_doc_topic_dist.to_csv('data/nk_doc_topic_dist.csv', index=False)

# %%
nk_doc_topic_dist = pd.read_csv('data/nk_doc_topic_dist.csv')

# %%
#Select 5 topics that no word missile included in top 10 words
def related_issue_event(num_event, unwanted_word, model, vectorizer, n_top_words):
    feature_names = vectorizer.get_feature_names()
    candidate_topic_idx = []
    for topic_idx, topic in enumerate(model.components_):
        if unwanted_word not in [ feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]:
            candidate_topic_idx.append(topic_idx)
    candidate_event_idx = []
    for candidate in candidate_topic_idx:
        candidate_event_idx.append(most_related_docs(df_nk, nk_doc_topic_dist, candidate, num_docs=1).index.tolist()[0])
        if len(candidate_event_idx) > num_event:
            break
    return candidate_event_idx

# %%
related_issue_index = related_issue_event(5, 'missile', nk_lda, nk_vectorizer, n_top_words=10)

# %%
# Extract entities from sentences
def extract_entity(sents, index, df):
    print("[ Detailed Information (per event) ]\n")
    
    ent_per = []
    ent_org = []
    ent_loc = []
    
    event = df.iloc[index].sort_values(by=['time'])['title'].tolist()
    
    for i in reversed(range(len(sents))):
        doc = nlp(sents[i])
        for ent in doc.ents:
            word = ent.text.title()
            if word in ent_per or word in ent_org or word in ent_loc:
                continue
            if ent.label_ == 'PERSON':
                ent_per.append(word)
            elif ent.label_ == 'ORG':
                ent_org.append(word)
            elif ent.label_ in ['GPE', 'LOC']:
                ent_loc.append(word)
        
        print("Event: ", event[i])
        print("- Person: ", ", ".join([i for i in ent_per]))
        print("- Organization: ", ", ".join([i for i in ent_org]))
        print("- Place: ", ", ".join([i for i in ent_loc]))
        print()

# %%
def print_events(df, index):
    event = df.iloc[index].sort_values(by=['time'])['title'].tolist()
    print("[ Related-Issue Events ]\n")
    print(", ".join([i for i in event]))
    print()

# %%
sents_nk = [ ' '.join(spacy_tokenizer(s)) for s in df.iloc[related_issue_index].sort_values(by=['time'])['body']]
print_events(df, related_issue_index)
extract_entity(sents_nk, related_issue_index, df)
# Out:
# [ Related-Issue Events ]
#
# N. Korea accepts Moscow's invitation for May visit: report, S. Korea, China urge N. Korea to halt nuclear activities, N. Korea denounces S. Korea's front-line fire exercise as military provocation, S. Korea unveils measures to support NK defectors, US issues latest travel warning for N. Korea, Number of N. Koreans seeking asylum in Europe drops
#
# [ Detailed Information (per event) ]
#
# Event:  Number of N. Koreans seeking asylum in Europe drops
# - Person:
# - Organization:  Eu Statistic Agency, Asylum European Union, European Free Trade Association
# - Place:  Europe, Yonhap)Among, Germany, Britain, Sweden, Luxembourg, Bulgaria, East Africa
#
# Event:  US issues latest travel warning for N. Korea
# - Person:  Kim Dong Chul
# - Organization:  Eu Statistic Agency, Asylum European Union, European Free Trade Association
# - Place:  Europe, Yonhap)Among, Germany, Britain, Sweden, Luxembourg, Bulgaria, East Africa, The United States, North Korea, Republic Korea, Pyongyang, Washington
#
# Event:  S. Korea unveils measures to support NK defectors
# - Person:  Kim Dong Chul, Kim Jong, Thae Yong Ho, North Embassy
# - Organization:  Eu Statistic Agency, Asylum European Union, European Free Trade Association, Hanawon Education Program, Seoul Unification Ministry
# - Place:  Europe, Yonhap)Among, Germany, Britain, Sweden, Luxembourg, Bulgaria, East Africa, The United States, North Korea, Republic Korea, Pyongyang, Washington, South Korea, London, Seoul
#
# Event:  N. Korea denounces S. Korea's front-line fire exercise as military provocation
# - Person:  Kim Dong Chul, Kim Jong, Thae Yong Ho, North Embassy
# - Organization:  Eu Statistic Agency, Asylum European Union, European Free Trade Association, Hanawon Education Program, Seoul Unification Ministry
# - Place:  Europe, Yonhap)Among, Germany, Britain, Sweden, Luxembourg, Bulgaria, East Africa, The United States, North Korea, Republic Korea, Pyongyang, Washington, South Korea, London, Seoul, South Korea Mark
#
# Event:  S. Korea, China urge N. Korea to halt nuclear activities
# - Person:  Kim Dong Chul, Kim Jong, Thae Yong Ho, North Embassy, Hwang Joon, Yongbyon Nuclear, Hwang, Wu Dawei, China Pledge
# - Organization:  Eu Statistic Agency, Asylum European Union, European Free Trade Association, Hanawon Education Program, Seoul Unification Ministry, Iaea
# - Place:  Europe, Yonhap)Among, Germany, Britain, Sweden, Luxembourg, Bulgaria, East Africa, The United States, North Korea, Republic Korea, Pyongyang, Washington, South Korea, London, Seoul, South Korea Mark, China, Japan, Russia
#
# Event:  N. Korea accepts Moscow's invitation for May visit: report
# - Person:  Kim Dong Chul, Kim Jong, Thae Yong Ho, North Embassy, Hwang Joon, Yongbyon Nuclear, Hwang, Wu Dawei, China Pledge, Kim Jong Un, Sergey Lavrov, Kim, Vladimir Putin, Choe Ryong Hae
# - Organization:  Eu Statistic Agency, Asylum European Union, European Free Trade Association, Hanawon Education Program, Seoul Unification Ministry, Iaea, Moscow Itar Tass News Agency, Air Force, Yonhap News Agency
# - Place:  Europe, Yonhap)Among, Germany, Britain, Sweden, Luxembourg, Bulgaria, East Africa, The United States, North Korea, Republic Korea, Pyongyang, Washington, South Korea, London, Seoul, South Korea Mark, China, Japan, Russia, Moscow, France, America
