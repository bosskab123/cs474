# %% [markdown]
# ### Libs & Data

# %%
import pandas as pd
import numpy as np
import os
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
import string
import random
import unicodedata
from string import punctuation
from string import digits
from nltk.stem import WordNetLemmatizer
import joblib

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt

import torch
from transformers import BartTokenizer, BartForConditionalGeneration, BartConfig

import spacy
from spacy.matcher import Matcher
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kwsst\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kwsst\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv("data/data_sum.csv")
df.shape
# Out:
# (23769, 7)

# %%
df.head()
# Out:
#                                                title         author  \
# 0      A snapshot of multiculturalism in South Korea  Lee Sun-young
# 1                   [Weekender] Korea’s dynamic 2017    Choi He-suk
# 2  People's Party members support Ahn's push for ...         Yonhap
# 3  [Newsmaker] Panamanian vessel probed over susp...         Yonhap
# 4  Hong Kong ship crew questioned in S. Korea for...            AFP
#
#                   time                                        description  \
# 0  2018-01-01 17:07:00  With birthrates persistently low and the senio...
# 1  2018-01-01 13:22:00  From North Korea’s nuclear weapons program nea...
# 2  2017-12-31 16:18:00  The leader of the center-left People's Party g...
# 3  2017-12-31 14:55:00  PYEONGTAEK  -- South Korea has seized and insp...
# 4  2017-12-30 15:44:00  The crew of a Hong Kong-registered ship have b...
#
#                                                 body         section  \
# 0  With birthrates persistently low and the senio...  Social affairs
# 1  From North Korea’s nuclear weapons program nea...  Social affairs
# 2  The leader of the center-left People's Party g...        Politics
# 3  PYEONGTAEK  -- South Korea has seized and insp...     North Korea
# 4  The crew of a Hong Kong-registered ship have b...     North Korea
#
#                                      summarized_body
# 0  As of 2016, more than 2 million foreign nation...
# 1  The corruption scandal that broke out in 2016 ...
# 2  Ahn Cheol-soo, leader of the center-left Peopl...
# 3  The 5,100-ton KOTI is being held in the wester...
# 4  The crew of a Hong Kong-registered ship have b...

# %%
# Load large spacy model 
nlp = spacy.load('en_core_web_lg')

# Aggregate title and content
title_weight = 1
df['agg_title_body'] = title_weight*(df['title']+'. ') + df['body']

# %%
df['agg_title_body'].str.contains("President Park Geun-hye's|President Park Geun-Hye's|President Park Geun Hye's|President Park Geun-hye|President Park Geun-Hye|President Park Geun Hye|President Park's|President Park|Park Geun-hye's|Park Geun-Hye's|Park Geun Hye's|Park Geun-Hye|Park Geun-hye|Park Geun Hye")
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 23764     True
# 23765     True
# 23766    False
# 23767    False
# 23768     True
# Name: agg_title_body, Length: 23769, dtype: object

# %%
park_str = "President Park Geun-hye's|President Park Geun-Hye's|President Park Geun Hye's|President Park Geun-hye|President Park Geun-Hye|President Park Geun Hye|President Park's|President Park|Park Geun-hye's|Park Geun-Hye's|Park Geun Hye's|Park Geun-Hye|Park Geun-hye|Park Geun Hye"
df_nk = df[(df['section']=='North Korea') & (df['agg_title_body'].str.contains('issile', flags=re.IGNORECASE, regex=True))]
df_politics = df[(df['section']=='Politics') & (df['agg_title_body'].str.contains(park_str, flags=re.IGNORECASE, regex=True))]

df_nk.to_csv("data/df_nk.csv", index=True)
df_politics.to_csv("data/df_politics.csv", index=True)

df_nk
# Out:
#                                                    title        author  \
# 3      [Newsmaker] Panamanian vessel probed over susp...        Yonhap
# 7      Secret Sauce? Kim Jong-un applies science to k...            AP
# 8      N. Korea says there will be no change to its n...        Yonhap
# 14     Top diplomats of S. Korea, US reassure peacefu...        Yonhap
# 19     Businessmen call for probe into shutdown of fa...        Yonhap
# ...                                                  ...           ...
# 23694  N. Korea likely to conduct series of nuclear, ...        KH디지털2
# 23727        Tension between U.S. and N. Korea escalates  Korea Herald
# 23739  U.S. slaps new sanctions on N. Korea in respon...           김영원
# 23757            U.S. places sanctions on N. Korean firm    Kim Yon-se
# 23767           U.S. imposes sanctions on N. Korean firm        KH디지털2
#
#                       time                                        description  \
# 3      2017-12-31 14:55:00  PYEONGTAEK  -- South Korea has seized and insp...
# 7      2017-12-30 12:10:00  Kim Jong Un wants to turn the art of kimchi-ma...
# 8      2017-12-30 10:31:00  North Korea will continue to enhance its nucle...
# 14     2017-12-29 16:31:00  The top diplomats of South Korea and the Unite...
# 19     2017-12-29 15:04:00  A private task force on Friday pressed the gov...
# ...                    ...                                                ...
# 23694  2015-01-06 10:22:00  The United States and South Korea should brace...
# 23727  2015-01-04 22:03:00  Tension between the United States and North Ko...
# 23739  2015-01-03 10:14:00  The United States announced retaliatory sancti...
# 23757  2015-01-01 21:22:00  The United States has imposed sanctions on a N...
# 23767  2015-01-01 09:25:00  The United States has imposed sanctions on a N...
#
#                                                     body      section  \
# 3      PYEONGTAEK  -- South Korea has seized and insp...  North Korea
# 7      Kim Jong Un wants to turn the art of kimchi-ma...  North Korea
# 8      North Korea will continue to enhance its nucle...  North Korea
# 14     The top diplomats of South Korea and the Unite...  North Korea
# 19     A private task force on Friday pressed the gov...  North Korea
# ...                                                  ...          ...
# 23694  The United States and South Korea should brace...  North Korea
# 23727  Tension between the United States and North Ko...  North Korea
# 23739  The United States announced retaliatory sancti...  North Korea
# 23757  The United States has imposed sanctions on a N...  North Korea
# 23767  The United States has imposed sanctions on a N...  North Korea
#
#                                          summarized_body  \
# 3      The 5,100-ton KOTI is being held in the wester...
# 7      Ryugyong Kimchi Factory produces 4,200 tons of...
# 8      North Korea will continue to enhance its nucle...
# 14     Top diplomats of South Korea and the U.S. held...
# 19     South Korea pulled the plug on the factory par...
# ...                                                  ...
# 23694  Victor Cha, chief Korea analyst at the Center ...
# 23727  U.S. President Barack Obama signed an executiv...
# 23739  Three North Korean entities and 10 officials a...
# 23757  Ryongaksan General Trading Corp. was on the li...
# 23767  The North's Ryongaksan General Trading Corp. w...
#
#                                           agg_title_body
# 3      [Newsmaker] Panamanian vessel probed over susp...
# 7      Secret Sauce? Kim Jong-un applies science to k...
# 8      N. Korea says there will be no change to its n...
# 14     Top diplomats of S. Korea, US reassure peacefu...
# 19     Businessmen call for probe into shutdown of fa...
# ...                                                  ...
# 23694  N. Korea likely to conduct series of nuclear, ...
# 23727  Tension between U.S. and N. Korea escalates. T...
# 23739  U.S. slaps new sanctions on N. Korea in respon...
# 23757  U.S. places sanctions on N. Korean firm. The U...
# 23767  U.S. imposes sanctions on N. Korean firm. The ...
#
# [2879 rows x 8 columns]

# %%
dfn = df[(df['section']=='North Korea') & (df['agg_title_body'].str.contains('Missile', flags=re.IGNORECASE, regex=True))]
dfn
# Out:
#                                                    title        author  \
# 3      [Newsmaker] Panamanian vessel probed over susp...        Yonhap
# 7      Secret Sauce? Kim Jong-un applies science to k...            AP
# 8      N. Korea says there will be no change to its n...        Yonhap
# 14     Top diplomats of S. Korea, US reassure peacefu...        Yonhap
# 19     Businessmen call for probe into shutdown of fa...        Yonhap
# ...                                                  ...           ...
# 23694  N. Korea likely to conduct series of nuclear, ...        KH디지털2
# 23727        Tension between U.S. and N. Korea escalates  Korea Herald
# 23739  U.S. slaps new sanctions on N. Korea in respon...           김영원
# 23757            U.S. places sanctions on N. Korean firm    Kim Yon-se
# 23767           U.S. imposes sanctions on N. Korean firm        KH디지털2
#
#                       time                                        description  \
# 3      2017-12-31 14:55:00  PYEONGTAEK  -- South Korea has seized and insp...
# 7      2017-12-30 12:10:00  Kim Jong Un wants to turn the art of kimchi-ma...
# 8      2017-12-30 10:31:00  North Korea will continue to enhance its nucle...
# 14     2017-12-29 16:31:00  The top diplomats of South Korea and the Unite...
# 19     2017-12-29 15:04:00  A private task force on Friday pressed the gov...
# ...                    ...                                                ...
# 23694  2015-01-06 10:22:00  The United States and South Korea should brace...
# 23727  2015-01-04 22:03:00  Tension between the United States and North Ko...
# 23739  2015-01-03 10:14:00  The United States announced retaliatory sancti...
# 23757  2015-01-01 21:22:00  The United States has imposed sanctions on a N...
# 23767  2015-01-01 09:25:00  The United States has imposed sanctions on a N...
#
#                                                     body      section  \
# 3      PYEONGTAEK  -- South Korea has seized and insp...  North Korea
# 7      Kim Jong Un wants to turn the art of kimchi-ma...  North Korea
# 8      North Korea will continue to enhance its nucle...  North Korea
# 14     The top diplomats of South Korea and the Unite...  North Korea
# 19     A private task force on Friday pressed the gov...  North Korea
# ...                                                  ...          ...
# 23694  The United States and South Korea should brace...  North Korea
# 23727  Tension between the United States and North Ko...  North Korea
# 23739  The United States announced retaliatory sancti...  North Korea
# 23757  The United States has imposed sanctions on a N...  North Korea
# 23767  The United States has imposed sanctions on a N...  North Korea
#
#                                          summarized_body  \
# 3      The 5,100-ton KOTI is being held in the wester...
# 7      Ryugyong Kimchi Factory produces 4,200 tons of...
# 8      North Korea will continue to enhance its nucle...
# 14     Top diplomats of South Korea and the U.S. held...
# 19     South Korea pulled the plug on the factory par...
# ...                                                  ...
# 23694  Victor Cha, chief Korea analyst at the Center ...
# 23727  U.S. President Barack Obama signed an executiv...
# 23739  Three North Korean entities and 10 officials a...
# 23757  Ryongaksan General Trading Corp. was on the li...
# 23767  The North's Ryongaksan General Trading Corp. w...
#
#                                           agg_title_body
# 3      [Newsmaker] Panamanian vessel probed over susp...
# 7      Secret Sauce? Kim Jong-un applies science to k...
# 8      N. Korea says there will be no change to its n...
# 14     Top diplomats of S. Korea, US reassure peacefu...
# 19     Businessmen call for probe into shutdown of fa...
# ...                                                  ...
# 23694  N. Korea likely to conduct series of nuclear, ...
# 23727  Tension between U.S. and N. Korea escalates. T...
# 23739  U.S. slaps new sanctions on N. Korea in respon...
# 23757  U.S. places sanctions on N. Korean firm. The U...
# 23767  U.S. imposes sanctions on N. Korean firm. The ...
#
# [2870 rows x 8 columns]

# %%
df_politics
# Out:
#                                                    title        author  \
# 21     Special pardons aimed at helping ordinary peop...        Yonhap
# 34     [News Focus] Is multiparty system viable in Ko...     Jo He-rim
# 37     Political parties call on government to resolv...     Jo He-rim
# 84     Korea's ODA project tainted by corruption scan...        Yonhap
# 174    Ex-President Park summoned for questioning Friday   Ock Hyun-ju
# ...                                                  ...           ...
# 23741                    Park trumpets unification drive  Korea Herald
# 23745  Park vows substantial preparations for unifica...           박한나
# 23751  Opposition leader calls on Park to focus on in...        KH디지털2
# 23758           Park vows efforts to end Korean division  Korea Herald
# 23759              Saenuri Party’s year rides on reforms  Korea Herald
#
#                       time                                        description  \
# 21     2017-12-29 11:39:00  The latest pardon extended to more than 6,000 ...
# 34     2017-12-28 16:29:00  A four-day vote of confidence in the People’s ...
# 37     2017-12-28 16:13:00  Political parties on Thursday expressed anger ...
# 84     2017-12-26 16:02:00  Impeached President Park Geun-hye's close frie...
# 174    2017-12-20 17:51:00  The prosecution summoned former President Park...
# ...                    ...                                                ...
# 23741  2015-01-02 21:36:00  President Park Geun-hye requested political le...
# 23745  2015-01-02 20:09:00  South Korean President Park Geun-hye pledged F...
# 23751  2015-01-02 11:17:00  The leader of the main opposition party called...
# 23758  2015-01-01 21:22:00  President Park Geun-hye on Thursday called for...
# 23759  2015-01-01 21:22:00  Rep. Kim Moo-sung, chairman of the Saenuri Par...
#
#                                                     body   section  \
# 21     The latest pardon extended to more than 6,000 ...  Politics
# 34     A four-day vote of confidence in the People’s ...  Politics
# 37     Political parties on Thursday expressed anger ...  Politics
# 84     Impeached President Park Geun-hye's close frie...  Politics
# 174    The prosecution summoned former President Park...  Politics
# ...                                                  ...       ...
# 23741  President Park Geun-hye requested political le...  Politics
# 23745  South Korean President Park Geun-hye pledged F...  Politics
# 23751  The leader of the main opposition party called...  Politics
# 23758  President Park Geun-hye on Thursday called for...  Politics
# 23759  Rep. Kim Moo-sung, chairman of the Saenuri Par...  Politics
#
#                                          summarized_body  \
# 21     The latest pardon extended to more than 6,000 ...
# 34     A four-day vote of confidence in the People’s ...
# 37     Political parties on Thursday expressed anger ...
# 84     The probe looked into allegations that the pri...
# 174    The prosecution summoned former President Park...
# ...                                                  ...
# 23741  President Park Geun-hye requested political le...
# 23745  South Korean President Park Geun-hye pledged F...
# 23751  The leader of the main opposition party called...
# 23758  President Park Geun-hye called for an end to t...
# 23759  Rep. Kim Moo-sung, chairman of the Saenuri Par...
#
#                                           agg_title_body
# 21     Special pardons aimed at helping ordinary peop...
# 34     [News Focus] Is multiparty system viable in Ko...
# 37     Political parties call on government to resolv...
# 84     Korea's ODA project tainted by corruption scan...
# 174    Ex-President Park summoned for questioning Fri...
# ...                                                  ...
# 23741  Park trumpets unification drive. President Par...
# 23745  Park vows substantial preparations for unifica...
# 23751  Opposition leader calls on Park to focus on in...
# 23758  Park vows efforts to end Korean division. Pres...
# 23759  Saenuri Party’s year rides on reforms. Rep. Ki...
#
# [2489 rows x 8 columns]

# %%
### Lemmatization tool
stemmer = WordNetLemmatizer()
### Change similar words to the same word
UN_WORD = "The United Nations"
US_WORD = "The United States"
NK_WORD = "North Korea"
SK_WORD = "South Korea"
PARK_WORD = "Park Geun-hye"

similar_words = {
    # Change to "The United States"
    "U.S.": US_WORD,
    "US": US_WORD,
    "USA": US_WORD,
    "United States": US_WORD,
    "United States'": US_WORD,
    "The United States'": US_WORD,
    
    # Change to "North Korea"
    "NK": NK_WORD,
    "NK's": NK_WORD,
    "N. Korea": NK_WORD,
    "N. Korea's": NK_WORD,
    "North Korea's": NK_WORD,
    
    # Change to "South Korea"
    "SK": SK_WORD,
    "SK's": SK_WORD,
    "S. Korea": SK_WORD,
    "S. Korea's": SK_WORD,
    "South Korea's": SK_WORD,
    
    # Change to "The United Nations"
    "United Nations": UN_WORD,
    "United Nations'": UN_WORD,
    "The United Nations'": UN_WORD,
    "UN": UN_WORD,
    
    # Change to "Park Geun-hye"
    "President Park Geun-hye's": PARK_WORD,
    "President Park Geun-Hye's": PARK_WORD,
    "President Park Geun Hye's": PARK_WORD,
    "President Park Geun-hye": PARK_WORD,
    "President Park Geun-Hye": PARK_WORD,
    "President Park Geun Hye": PARK_WORD,
    "President Park's": PARK_WORD,
    "President Park": PARK_WORD,
    "Park Geun-hye's": PARK_WORD,
    "Park Geun-Hye's": PARK_WORD,
    "Park Geun Hye's": PARK_WORD,
    "Park Geun-Hye": PARK_WORD,
    "Park Geun Hye": PARK_WORD,
}

### Transform function
def text_cleaning(s: str):
        
    def replace_strange_char(s: str):
        non_en_chars = {
            "’": "'",
            "‘": "'"
        }

        def remove_non_en_chars(txt):
            # remove non english characters
            txt = convert_latin_chars(txt)
            for char in non_en_chars.keys():
                txt = re.sub(char, non_en_chars[char], txt)
            txt = re.sub(r'[^\x00-\x7F]+', ' ', txt)
            return txt

        def convert_latin_chars(txt):
            # convert latin characters
            return ''.join(char for char in unicodedata.normalize('NFKD', txt) if unicodedata.category(char) != 'Mn')

        s = remove_non_en_chars(s)
        s = convert_latin_chars(s)
        return s
    s = replace_strange_char(s)
    for key,value in similar_words.items():
        s = re.sub(key, value, s)
    return s

def spacy_tokenizer(s: str):
    # Change similar terms to the same term
    new_str = text_cleaning(s)
    doc = nlp(s)
    # Group tokens
    matcher = Matcher(nlp.vocab)
    token_groupup_pattern = [
        [{"LOWER": "the"}, {"LOWER": "united"}, {"LOWER": "nations"}],
        [{"LOWER": "the"}, {"LOWER": "united"}, {"LOWER": "states"}],
        [{"LOWER": "north"}, {"LOWER": "korea"}],
        [{"LOWER": "south"}, {"LOWER": "korea"}],
    ]
    matcher.add("TermGroup",token_groupup_pattern)
    matches = matcher(doc)
    merge_doc = []
    for nid, start, end in matches:
        merge_doc.append((start,end))
    with doc.retokenize() as retokenizer:
        for i in range(len(merge_doc)-1,-1,-1):
            retokenizer.merge(doc[merge_doc[i][0]:merge_doc[i][1]])
        
    # Remove all stopword, punctuation, number
    tokens = [ token.lemma_.lower() for token in doc \
              if not token.is_stop and not token.is_punct and not token.like_num and token.lemma_.strip()!= '']
    return tokens

### Preprocess function for grouping similar topic
def preprocess_manual(s: str):
    # Change similar words to the same word
    new_str = transform_to_similar_sentence(s)
    # Remove punctuation
    new_str = ''.join(ch if ch not in set(punctuation) else " " for ch in new_str)
    # Remove all single characters
    new_str = re.sub(r'\W', ' ', new_str)
    new_str = re.sub(r'\s+[a-zA-Z]\s+', ' ', new_str)
    new_str = re.sub(r'\^[a-zA-Z]\s+', ' ', new_str) 
    # Substituting multiple spaces with single space
    new_str = re.sub(r'\s+', ' ', new_str, flags=re.I)
    # Removing prefixed 'b' - when data is in bytes format
    new_str = re.sub(r'^b\s+', '', new_str)
    # Removing all numbers
    new_str = new_str.translate(str.maketrans('', '', digits))
    # Converting to Lowercase
    new_str = new_str.lower()
    # Lemmatization and remove stopwords
    new_str = new_str.split()
    stopwords = nltk.corpus.stopwords.words('english')
    tokens = [stemmer.lemmatize(word) for word in new_str if word not in stopwords]
    new_str = ' '.join(tokens)
    
    return new_str, tokens

# %%
### Make TF-IDF matrix
def tfidf_embed(documents, dimension=None):
    # documents: list of str
    # dim: integer
    embeddings_dict = {}
    tfidf_vectorizer = TfidfVectorizer(input='content', tokenizer=spacy_tokenizer)
    tfidf_vector = tfidf_vectorizer.fit_transform(documents)
    
    # Dimensionality Reduction
    if dimension is not None:
        svd_doc = TruncatedSVD(n_components=dimension, n_iter=5, random_state=42)
        tfidf_vector = svd_doc.fit_transform(tfidf_vector)
    return tfidf_vector

### Make GloVe matrix
glove_file = "../glove.42B.300d.txt"
def glove_word_vector():
    embeddings_dict = {}
    with open(glove_file, 'r') as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], "float32")
            embeddings_dict[word] = vector
    return embeddings_dict

# Average sum of word vectors
def sentence_embed(sentence, word_vectors, dimension):
    sum_vector = np.zeros(dimension)
    for w in sentence.split():
        if w in word_vectors:
            sum_vector += word_vectors[w]
    return sum_vector/len(sentence)

# Make document vector
def document_embed(documents, embedding_technique='tfidf', dimension=None):
    if embedding_technique=='tfidf':
        doc_vector = tfidf_embed(documents, dimension)
    elif embedding_technique=='glove':
        word_vector = glove_word_vector()
        if dimension is None:
            dimension = 300
        doc_vector = [ sentence_embed(s, word_vector, dimension).tolist() for s in documents ]
    elif embedding_technique=='spacy':
        doc_vector = [doc.vector for doc in documents]
    
    return doc_vector

# %%
# park_str = "President Park Geun-hye's|President Park Geun-Hye's|President Park Geun Hye's|President Park Geun-hye|President Park Geun-Hye|President Park Geun Hye|President Park's|President Park|Park Geun-hye's|Park Geun-Hye's|Park Geun Hye's|Park Geun-Hye|Park Geun-hye|Park Geun Hye"
# nk_str = "North Korea|North Korea's|NK|NK's|N. Korea"

# df_park = df[df['body'].str.contains(park_str, na=False, flags=re.IGNORECASE, regex=True)]
# df_park

# %%
tfidf_nk = document_embed(df_nk['agg_title_body'], embedding_technique='tfidf', dimension=300)
joblib.dump(tfidf_nk, 'tfidf_nk.csv')
print("TDIDF_NK is saved")
# Out:
# TDIDF_NK is saved

# %%
tfidf_politics = document_embed(df_politics['agg_title_body'], embedding_technique='tfidf', dimension=300)
joblib.dump(tfidf_politics, 'tfidf_politics.csv')
print("TDIDF_POLITICS is saved")
# Out:
# TDIDF_POLITICS is saved

# %%
# tfidf_nk_politics = document_embed(df_nk_politics, embedding_technique='tfidf', dimension=300)
# joblib.dump(tfidf_nk_politics, 'tfidf_nk.csv')
# print("TDIDF_NK_POLITICS is saved")
