# %%
import numpy as np 
import pandas as pd
import os
import re

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import spacy
from spacy.matcher import Matcher

from scipy.spatial.distance import jensenshannon

import joblib

from IPython.display import HTML, display

from ipywidgets import interact, Layout, HBox, VBox, Box
import ipywidgets as widgets
from IPython.display import clear_output

from tqdm import tqdm
from os.path import isfile

import unicodedata
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data_dir = 'data/'
filename_prefix = 'koreaherald_1517_'
df = []

for i in range(8):
    df.append(pd.read_json(os.path.join(data_dir, filename_prefix + str(i) + '.json')))
df = pd.concat(df)
df.reset_index(inplace=True)
df = df.rename(columns=dict(zip(df.columns,[df.columns[i].strip() for i in range(len(df.columns))])))
df.drop('index', inplace=True, axis=1)

# Load preprocessed data
df['summarized_body'] = pd.read_csv('summarized_data.csv')

df.shape
# Out:
# (23769, 7)

# %%
nlp = spacy.load('en_core_web_lg')

### Change similar words to the same word
UN_WORD = "The United Nations"
US_WORD = "The United States"
NK_WORD = "North Korea"
SK_WORD = "South Korea"

similar_words = {
    # Change to "The United States"
    "U.S.": US_WORD,
    "US": US_WORD,
    "USA": US_WORD,
    "United States": US_WORD,
    "United States'": US_WORD,
    "The United States'": US_WORD,
    
    # Change to "North Korea"
    "NK": NK_WORD,
    "NK's": NK_WORD,
    "N. Korea": NK_WORD,
    "N. Korea's": NK_WORD,
    "North Korea's": NK_WORD,
    
    # Change to "South Korea"
    "SK": SK_WORD,
    "SK's": SK_WORD,
    "S. Korea": SK_WORD,
    "S. Korea's": SK_WORD,
    "South Korea's": SK_WORD,
    
    # Change to "The United Nations"
    "United Nations": UN_WORD,
    "United Nations'": UN_WORD,
    "The United Nations'": UN_WORD,
    "UN": UN_WORD,
}

### Transform function
def text_cleaning(s: str):
    for key,value in similar_words.items():
        s = re.sub(key, value, s)
        
    def replace_strange_char(s: str):
        non_en_chars = {
            "’": "'",
            "‘": "'"
        }

        def remove_non_en_chars(txt):
            # remove non english characters
            txt = convert_latin_chars(txt)
            for char in non_en_chars.keys():
                txt = re.sub(char, non_en_chars[char], txt)
            txt = re.sub(r'[^\x00-\x7F]+', ' ', txt)
            return txt

        def convert_latin_chars(txt):
            # convert latin characters
            return ''.join(char for char in unicodedata.normalize('NFKD', txt) if unicodedata.category(char) != 'Mn')

        s = remove_non_en_chars(s)
        s = convert_latin_chars(s)
        return s
    s = replace_strange_char(s)
    return s

def spacy_tokenizer(s: str):
    # Change similar terms to the same term
    new_str = text_cleaning(s)
    doc = nlp(s)
    # Group tokens
    matcher = Matcher(nlp.vocab)
    token_groupup_pattern = [
        [{"LOWER": "the"}, {"LOWER": "united"}, {"LOWER": "nations"}],
        [{"LOWER": "the"}, {"LOWER": "united"}, {"LOWER": "states"}],
        [{"LOWER": "north"}, {"LOWER": "korea"}],
        [{"LOWER": "south"}, {"LOWER": "korea"}],
    ]
    matcher.add("TermGroup",token_groupup_pattern)
    matches = matcher(doc)
    merge_doc = []
    for nid, start, end in matches:
        merge_doc.append((start,end))
    with doc.retokenize() as retokenizer:
        for i in range(len(merge_doc)-1,-1,-1):
            retokenizer.merge(doc[merge_doc[i][0]:merge_doc[i][1]])
        
    # Remove all stopword, punctuation, number
    tokens = [ token.lemma_.lower() for token in doc \
              if not token.is_stop and not token.is_punct and not token.like_num and token.lemma_.strip()!= '']
    return tokens

# %%
vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, min_df=2)
all_texts = df['title']
data_vectorized = vectorizer.fit_transform(tqdm(all_texts))

# most frequent words
word_count = pd.DataFrame({'word': vectorizer.get_feature_names(), 'count': np.asarray(data_vectorized.sum(axis=0))[0]})

word_count.sort_values('count', ascending=False).set_index('word')[:20].sort_values('count', ascending=True).plot(kind='barh')
# Out:
#   6%|████▋                                                                         | 1434/23769 [00:19<04:56, 75.38it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12981/522682159.py in <module>
#       1 vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, min_df=2)
#       2 all_texts = df['title']
# ----> 3 data_vectorized = vectorizer.fit_transform(tqdm(all_texts))
#       4
#       5 # most frequent words
#
# ~/miniconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1328                     break
#    1329
# -> 1330         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1331
#    1332         if self.binary:
#
# ~/miniconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1199         for doc in raw_documents:
#    1200             feature_counter = {}
# -> 1201             for feature in analyze(doc):
#    1202                 try:
#    1203                     feature_idx = vocabulary[feature]
#
# ~/miniconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     113             doc = preprocessor(doc)
#     114         if tokenizer is not None:
# --> 115             doc = tokenizer(doc)
#     116         if ngrams is not None:
#     117             if stop_words is not None:
#
# /tmp/ipykernel_12981/3927601681.py in spacy_tokenizer(s)
#      69     # Change similar terms to the same term
#      70     new_str = text_cleaning(s)
# ---> 71     doc = nlp(s)
#      72     # Group tokens
#      73     matcher = Matcher(nlp.vocab)
#
# ~/miniconda3/lib/python3.9/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     443             if not hasattr(proc, "__call__"):
#     444                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 445             doc = proc(doc, **component_cfg.get(name, {}))
#     446             if doc is None:
#     447                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     293     def begin_update(seqs_in, drop=0.0):
#     294         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 295         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     296         if bp_layer is None:
#     297             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      27
#      28     def begin_update(self, X, drop=0.0):
# ---> 29         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      30         if isinstance(X, list):
#      31             output = [X[i] + y[i] for i in range(len(X))]
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      60     def begin_update(self, X, drop=0.0):
#      61         if self.child is not None:
# ---> 62             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      63         else:
#      64             backprop_child = None
#
# ~/miniconda3/lib/python3.9/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      74         if drop is not None:
#      75             drop *= self.drop_factor
# ---> 76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
joblib.dump(vectorizer, 'vectorizer_title.csv')
joblib.dump(data_vectorized, 'title_vectorized.csv')

# %%
# Load doc vector (Count Vector)
vectorizer = joblib.load('vectorizer.csv')
data_vectorized = joblib.load('data_vectorized.csv')

# %%
lda2015 = LatentDirichletAllocation(n_components=100, random_state=0)
lda2015.fit(data_vectorized[ (df['time'] < '2016') & (df['time']>'2015')])
joblib.dump(lda2015, 'lda_title_2015.csv')

lda2016 = LatentDirichletAllocation(n_components=100, random_state=0)
lda2016.fit(data_vectorized[(df['time'] < '2017') & (df['time']>'2016')])
joblib.dump(lda2016, 'lda_title_2016.csv')

lda2017 = LatentDirichletAllocation(n_components=100, random_state=0)
lda2017.fit(data_vectorized[(df['time'] < '2018') & (df['time']>'2017')])
joblib.dump(lda2017, 'lda_title_2017.csv')
# Out:
# ['lda_title_2017.csv']

# %%
# Load model LDA
lda2015 = joblib.load('lda_title_2015.csv')
lda2016 = joblib.load('lda_title_2016.csv')
lda2017 = joblib.load('lda_title_2017.csv')

# %%
def print_top_words(model, vectorizer, n_top_words):
    feature_names = vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        message = "\nTopic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
print_top_words(lda2015, vectorizer, n_top_words=25)
# Out:
# Topic #0: wage worker percent pay job $ park minimum korean north march approval employee company raise government won firm week poll month tax rating approve seoul
#
# Topic #1: china state u.s secretary say dispute beijing kerry russel sea assistant john official washington call territorial south korea daniel south change run international tension security resolution
#
# Topic #2: say korean north korea report shin royce foreign u.n special rep commission dong ed marzuki darusman inquiry south north commander right holiday hyuk introduce relevant detail
#
# Topic #81: house philippines white week meeting sideline manila group base produce disclose new health youb chin believe service national hyung away chung pacific plan trudeau lukewarm
#
# Topic #82: chul app ki need monitoring local late country measure require south korea launch kakao daum offer charge salvage follow naval user space center ju driver arrest
#
# Topic #83: korean north south north korea koreas inter border talk hold war reunion pyongyang family level visit tension military separate agree aug seoul day side lee early
#
# Topic #84: park yoo min seong rating tae hye test anti geun olympic positive time floor doping poll hwan lead appear say african speak week substance world
#
# Topic #85: threat china want potential say south korea korea center u.s seoul security beijing counter unit permanent committee expert grow country research defense deployment asset seminar individual
#
# Topic #86: water base seoul country government korea design event world waste won $ ton invest run military resource come facility nation say large metropolitan tripartite personnel
#
# Topic #87: staff chairman adm joint gen chief chiefs force choi navy hee army jung group bribe briefing retire air year $ receive conglomerate ok take sun
#
# Topic #88: education textbook government history school ministry state say high announce plan author teacher middle decision korean student group private office system year secondary ahead participate
#
# Topic #89: science injury need preliminary run south korea unification open country include structure hospital plan head expert cut event air day yoon seoul reservist council industry support
#
# Topic #90: professor university history publish different woo country yea education hwang say author government national claim minister write criticize institute korea brother lead present work public
#
# Topic #91: intelligence agency national cyber attack say hacking service nis sony report military deny computer news south korea north korea hack purchase internet control central security tell north
#
# Topic #92: vice cho minister visit foreign tae schedule official yong secretary trip state attention u.s yul draw expect security meet hyun korean ah seoul year ri
#
# Topic #93: south country people newspaper georgia korean sinmun rodong embassy war equipment year rep institute south korea u.s rason open say hit min unit goni particularly erect
#
# Topic #94: percent survey energy nuclear respondent say year spend power korea agreement new fuel surge country cooperation show south korea market compare plant percentage conduct nearly point
#
# Topic #95: say korean korea day south system report hold week seoul chance help plan medium country head promote include call offer consider lecture pack long come
#
# Topic #96: city province port china navy bus marine dust chinese warning bridge naval say southern northeastern busan destroyer yellow south aircraft fleet gyeonggi facility corps force
#
# Topic #97: south korea fire claim military sea islet border troop dokdo artillery south korean island north say line drill readiness combat report easternmost unit call near country
#
# Topic #98: city seoul soon mayor win government gyeonggi close province world year park have shut release provincial implement problem suffer public cancer lung kwon elderly plan
#
# Topic #99: north korea nuclear talk program north pyongyang party china stall weapon u.s denuclearization late long aid resume envoy humanitarian dormant beijing dialogue hold year washington chinese

# %%
doc_topic_dist = pd.DataFrame(lda.transform(data_vectorized))
doc_topic_dist.to_csv('doc_topic_dist.csv', index=False)

# %%
def get_k_nearest_docs(doc_dist, year, k=5, get_dist=False):
    '''
    doc_dist: topic distribution (sums to 1) of one article
    
    Returns the index of the k nearest articles (as by Jensen–Shannon divergence in topic space). 
    '''
    
    temp = doc_topic_dist[df['date'] < year & df['date'] > year-1]
         
    distances = temp.apply(lambda x: jensenshannon(x, doc_dist), axis=1)
    k_nearest = distances[distances != 0].nsmallest(n=k).index
    
    if get_dist:
        k_distances = distances[distances != 0].nsmallest(n=k)
        return k_nearest, k_distances
    else:
        return k_nearest

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda.score(data_vectorized))

# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda.perplexity(data_vectorized))

# See model parameters
print(lda.get_params())
