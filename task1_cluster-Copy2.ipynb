# %%
### Libs & Data

# %%
import pandas as pd
import numpy as np
import os
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
import string
import random
import unicodedata
from string import punctuation
from string import digits
from nltk.stem import WordNetLemmatizer
import joblib

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt

import torch
from transformers import BartTokenizer, BartForConditionalGeneration, BartConfig

import spacy
from spacy.matcher import Matcher
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Modern\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Modern\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv("data/data_sum.csv")
df.shape
# Out:
# (23769, 7)

# %%
df.head()
# Out:
#                                                title         author  \
# 0      A snapshot of multiculturalism in South Korea  Lee Sun-young
# 1                   [Weekender] Korea’s dynamic 2017    Choi He-suk
# 2  People's Party members support Ahn's push for ...         Yonhap
# 3  [Newsmaker] Panamanian vessel probed over susp...         Yonhap
# 4  Hong Kong ship crew questioned in S. Korea for...            AFP
#
#                   time                                        description  \
# 0  2018-01-01 17:07:00  With birthrates persistently low and the senio...
# 1  2018-01-01 13:22:00  From North Korea’s nuclear weapons program nea...
# 2  2017-12-31 16:18:00  The leader of the center-left People's Party g...
# 3  2017-12-31 14:55:00  PYEONGTAEK  -- South Korea has seized and insp...
# 4  2017-12-30 15:44:00  The crew of a Hong Kong-registered ship have b...
#
#                                                 body         section  \
# 0  With birthrates persistently low and the senio...  Social affairs
# 1  From North Korea’s nuclear weapons program nea...  Social affairs
# 2  The leader of the center-left People's Party g...        Politics
# 3  PYEONGTAEK  -- South Korea has seized and insp...     North Korea
# 4  The crew of a Hong Kong-registered ship have b...     North Korea
#
#                                      summarized_body
# 0  As of 2016, more than 2 million foreign nation...
# 1  The corruption scandal that broke out in 2016 ...
# 2  Ahn Cheol-soo, leader of the center-left Peopl...
# 3  The 5,100-ton KOTI is being held in the wester...
# 4  The crew of a Hong Kong-registered ship have b...

# %%
df2015 = df[('2015' < df['time']) & (df['time'] < '2016')]
df2016 = df[('2016' < df['time']) & (df['time'] < '2017')]
df2017 = df['2017' < df['time']]

# %%
df2015.shape, df2016.shape, df2017.shape
# Out:
# ((7156, 7), (7485, 7), (9128, 7))

# %%
### Clustering 
def document_clustering(doc_vectors, clustering_method='kmeans', evaluate=False):
    if clustering_method=='kmeans':
        # Hyperparameters
        k_event = 10000
        k_issue = 6000
        
        # Clustering event
        kmeans_event = KMeans(n_clusters=k_event, random_state=69).fit(doc_vectors)
        # Represent each event by average sum of related news
        event_vectors = np.zeros((k_event, doc_vectors.shape[1]))
        for i in range(k_event):
            event_vectors[i] = sum(doc_vectors[kmeans_event.labels_ == i])
        
        # Clustering issue
        kmeans_issue = KMeans(n_clusters=k_issue, random_state=69).fit(event_vectors)
        # Represent each issue by average sum of related news
        issue_vectors = np.zeros((k_issue, doc_vectors.shape[1]))
        for i in range(k_issue):
            issue_vectors[i] = sum(event_vectors[kmeans_issue.labels_ == i])

        issue_labels = np.array([ kmeans_issue.labels_[kmeans_event.labels_[i]] for i in range(doc_vectors.shape[0]) ])
        
        return k_issue, k_event, issue_labels, kmeans_event.labels_
    
    elif clustering_method=='DBSCAN':
        
        # Hyperparameters
        doc_eps = 0.40
        doc_neighbors = 1
        event_eps = 0.60
        event_neighbors = 1
        
        '''
            Find best doc_eps and event_eps
        '''
        if evaluate:
            # Find best eps to group same document
            doc_eps_list = [ 0.15 + 0.001*i for i in range(1,101) ]
            doc_score = []
            doc_event = []
            doc_best_score = 0
            doc_best_eps = 0.0001
            for doc_eps in doc_eps_list:
                # Clustering event
                db_event = DBSCAN(eps=doc_eps, min_samples=doc_neighbors).fit(doc_vectors)
                # Number of clusters in labels, ignoring noise if present.
                n_events_ = len(set(db_event.labels_)) - (1 if -1 in db_event.labels_ else 0)
                if len(set(db_event.labels_)) >= 2 and len(set(db_event.labels_)) <= len(doc_vectors)-1:
                    score_ = silhouette_score(doc_vectors, db_event.labels_)
                else:
                    score_ = -1
                doc_event.append(n_events_)
                doc_score.append(score_)
                if score_ > doc_best_score:
                    doc_best_score = score_
                    doc_best_eps = doc_eps
            print("Best Silhouete score is {} at eps: {} and number of events: {}".format(doc_best_score, doc_eps, n_events_))
            fig = plt.figure()
            plt.plot(doc_eps_list, doc_score)
            fig.suptitle('Doc eps and Silhouette score', fontsize=20)
            plt.xlabel('eps', fontsize=18)
            plt.ylabel('Silhouette score', fontsize=16)
            plt.show()
            
            fig = plt.figure()
            plt.plot(doc_eps_list, doc_event)
            fig.suptitle('Doc eps and number of events', fontsize=20)
            plt.xlabel('eps', fontsize=18)
            plt.ylabel('number of events', fontsize=16)
            plt.show()
            
            # Set doc_eps to the best value
            doc_eps = doc_best_eps
            # Find best eps to group same event
            # Clustering event
            db_event = DBSCAN(eps=doc_eps, min_samples=doc_neighbors).fit(doc_vectors)
            n_events_ = len(set(db_event.labels_)) - (1 if -1 in db_event.labels_ else 0)
            event_labels = np.array(list(map(lambda x: n_events_ if x==-1 else x, db_event.labels_)))
            event_vectors = np.zeros((n_events_, doc_vectors.shape[1]))
            for i in range(n_events_+1):
                if np.sum(event_labels == i) != 0:
                    event_vectors[i] = np.sum(doc_vectors[event_labels == i], axis=0)/np.sum(event_labels == i)
            
            
#             # Clustering issue
#             event_eps_list = [ 0.2 + 0.001*i for i in range(1,401) ]
#             event_score = []
#             event_issue = []
#             event_best_score = 0
#             event_best_eps = 0.001
#             for event_eps in event_eps_list:
#                 db_issue = DBSCAN(eps=event_eps, min_samples=event_neighbors).fit(event_vectors)
#                 # Number of clusters in labels, ignoring noise if present.
#                 n_issues_ = len(set(db_issue.labels_)) - (1 if -1 in db_issue.labels_ else 0)
#                 if len(set(db_issue.labels_)) >= 2 and len(set(db_issue.labels_)) <= len(event_vectors)-1:
#                     score_ = silhouette_score(event_vectors, db_issue.labels_)
#                 else:
#                     score_ = -1
#                 event_issue.append(n_issues_)
#                 event_score.append(score_)
#                 if score_ > event_best_score:
#                     event_best_score = score_
#                     event_best_eps = event_eps
#             print("Best Silhouete score is {} at eps: {} and number of issues: {}".format(event_best_score, event_eps, n_issues_))
#             fig = plt.figure()
#             plt.plot(event_eps_list, event_score)
#             fig.suptitle('Event eps and Silhouette score', fontsize=20)
#             plt.xlabel('eps', fontsize=18)
#             plt.ylabel('Silhouette score', fontsize=16)
#             plt.show()
            
#             fig = plt.figure()
#             plt.plot(event_eps_list, event_issue)
#             fig.suptitle('Event eps and number of issues', fontsize=20)
#             plt.xlabel('eps', fontsize=18)
#             plt.ylabel('number of issues', fontsize=16)
#             plt.show()
            
            # Set event_eps to best value
            event_eps = 0.5
            # Clustering issue
            db_issue = DBSCAN(eps=event_eps, min_samples=event_neighbors).fit(event_vectors)
            # Number of clusters in labels, ignoring noise if present.
            n_issues_ = len(set(db_issue.labels_)) - (1 if -1 in db_issue.labels_ else 0)
            n_noise_ = list(db_issue.labels_).count(-1)
            print(n_issues_, n_noise_)
            # Represent each issue by average sum of related news
            issue_labels = np.array(list(map(lambda x: n_issues_ if x==-1 else x, db_issue.labels_)))
            issue_vectors = np.zeros((n_issues_, doc_vectors.shape[1]))
            for i in range(n_issues_+1):
                if np.sum(issue_labels == i) != 0:
                    issue_vectors[i] = np.sum(event_vectors[issue_labels == i], axis=0)/np.sum(issue_labels == i)
       
            issue_labels = np.array([ issue_labels[event_labels[i]] for i in range(doc_vectors.shape[0]) ])
        
        else:
            '''
            Clustering using specific value
            '''
            # Clustering event
            db_event = DBSCAN(eps=doc_eps, min_samples=doc_neighbors).fit(doc_vectors)
            # Number of clusters in labels, ignoring noise if present.
            n_events_ = len(set(db_event.labels_)) - (1 if -1 in db_event.labels_ else 0)
            n_noise_ = list(db_event.labels_).count(-1)
            print(n_events_, n_noise_)
            # Represent each event by average sum of related news
            event_labels = np.array(list(map(lambda x: n_events_ if x==-1 else x, db_event.labels_)))
            event_vectors = np.zeros((n_events_, doc_vectors.shape[1]))
            for i in range(n_events_+1):
                if np.sum(event_labels == i) != 0:
                    event_vectors[i] = np.sum(doc_vectors[event_labels == i], axis=0)/np.sum(event_labels == i)

            # Clustering issue
            db_issue = DBSCAN(eps=event_eps, min_samples=event_neighbors).fit(event_vectors)
            # Number of clusters in labels, ignoring noise if present.
            n_issues_ = len(set(db_issue.labels_)) - (1 if -1 in db_issue.labels_ else 0)
            n_noise_ = list(db_issue.labels_).count(-1)
            print(n_issues_, n_noise_)
            # Represent each issue by average sum of related news
            issue_labels = np.array(list(map(lambda x: n_issues_ if x==-1 else x, db_issue.labels_)))
            issue_vectors = np.zeros((n_issues_, doc_vectors.shape[1]))
            for i in range(n_issues_+1):
                if np.sum(issue_labels == i) != 0:
                    issue_vectors[i] = np.sum(event_vectors[issue_labels == i], axis=0)/np.sum(issue_labels == i)
        
            issue_labels = np.array([ issue_labels[event_labels[i]] for i in range(doc_vectors.shape[0]) ])
        
        return n_issues_, n_events_, issue_labels, event_labels
    
    elif clustering_method=='agglomerative':
        # Hyperparameters
        n_events = 10000
        n_issues = 6000
        
        # Clustering event
        agg_event = AgglomerativeClustering(distance_threshold=0, n_clusters=n_events).fit(doc_vectors)
        # Represent each event by average sum of related news
        event_vectors = np.zeros((n_events, doc_vectors.shape[1]))
        for i in range(n_events):
            event_vectors[i] = sum(doc_vectors[agg_event.labels_ == i])
        
        plt.title("Hierarchical Clustering Dendrogram")
        # plot the top three levels of the dendrogram
        plot_dendrogram(agg_event, truncate_mode="level", p=3)
        plt.xlabel("Number of points in node (or index of point if no parenthesis).")
        plt.show()
        
        # Clustering issue
        agg_issue = AgglomerativeClustering(distance_threshold=0, n_clusters=n_issues).fit(event_vectors)
        # Represent each issue by average sum of related news
        issue_vectors = np.zeros((n_issues, doc_vectors.shape[1]))
        for i in range(n_issues):
            issue_vectors[i] = sum(event_vectors[agg_issue.labels_ == i])

        issue_labels = np.array([ agg_issue.labels_[agg_event.labels_[i]] for i in range(doc_vectors.shape[0]) ])
        
        return agg_issue, agg_event, issue_labels, agg_event.labels_
    
    elif clustering_method=='LDA':
        
        pass
    
    else:
        assert("Doesn't support {}".format(clustering_method))

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %% [markdown]
# ### Import the embedded documents

# %%
vects_2015 = joblib.load('data/tfidf_titlebody_2015.csv')
vects_2016 = joblib.load('data/tfidf_titlebody_2016.csv')
vects_2017 = joblib.load('data/tfidf_titlebody_2017.csv')

# %% [markdown]
# ### Cluster

# %%
num_issue_2015, num_event_2015, issue_labels_2015, event_labels_2015 = document_clustering(vects_2015,
                                                                                           clustering_method='DBSCAN',
                                                                                           evaluate=False)
# Out:
# 4087 0
# 55 0

# %%
num_issue_2016, num_event_2016, issue_labels_2016, event_labels_2016 = document_clustering(vects_2016,
                                                                                           clustering_method='DBSCAN',
                                                                                           evaluate=False)
# Out:
# 4725 0
# 44 0

# %%
num_issue_2017, num_event_2017, issue_labels_2017, event_labels_2017 = document_clustering(vects_2017,
                                                                                           clustering_method='DBSCAN',
                                                                                           evaluate=False)
# Out:
# 5624 0
# 54 0

# %%
# Add label to each doc (which group it belongs to)
df2015['label'] = event_labels_2015
df2015.head()
# Out:
# C:\Users\Modern\AppData\Local\Temp/ipykernel_20596/2903645881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2015['label'] = event_labels_2015
#                                                    title         author  \
# 16613         S. Korea, China establish military hotline            김영원
# 16614                FM Yun defends 'comfort women' deal  Kim Young-won
# 16615  Presidential office refutes rumors on Seoul-To...         KH디지털2
# 16616                 Assembly ends with little achieved            이주희
# 16617        Non-emergency patients to face ER fee hikes            이주희
#
#                       time                                        description  \
# 16613  2015-12-31 16:52:00  South Korea and China set up a hotline between...
# 16614  2015-12-31 16:48:00  Foreign Minister Yun Byung-se stepped up effor...
# 16615  2015-12-31 15:52:00  Cheong Wa Dae, South Korea's presidential offi...
# 16616  2015-12-31 15:33:00  The National Assembly held its last general as...
# 16617  2015-12-31 15:31:00  Non-emergency patients will face much higher m...
#
#                                                     body         section  \
# 16613  South Korea and China set up a hotline between...         Defense
# 16614  Foreign Minister Yun Byung-se stepped up effor...             NaN
# 16615  Cheong Wa Dae, South Korea's presidential offi...        Politics
# 16616  The National Assembly held its last general as...  Social affairs
# 16617  Non-emergency patients will face much higher m...  Social affairs
#
#                                          summarized_body  label
# 16613  Defense Minister Han Min-koo had his first tel...      0
# 16614  Foreign Minister Yun Byung-se steps up efforts...      1
# 16615  South Korea's presidential office refuted rumo...      2
# 16616  Parliamentary Speaker Chung Ui-hwa said that h...      3
# 16617  Non-emergency patients will face much higher m...      4

# %%
df2016['label'] = event_labels_2016
df2016.head()
# Out:
# C:\Users\Modern\AppData\Local\Temp/ipykernel_20596/4095929450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2016['label'] = event_labels_2016
#                                                   title author  \
# 9128  Chinese airlines withdraw plans for chartered ...    조정은
# 9129  Ex-health minister grilled over scandal involv...    조정은
# 9130  Highly pathogenic strain of bird flu found in ...    조정은
# 9131  S. Koreans demand president's removal on New Y...    조정은
# 9132  S. Korea's pension fund chief formally arreste...    조정은
#
#                      time                                        description  \
# 9128  2016-12-31 16:36:00  Chinese airlines have withdrawn plans to run c...
# 9129  2016-12-31 16:14:00  South Korea's special prosecutors on Saturday ...
# 9130  2016-12-31 12:09:00  A highly pathogenic strain of bird flu was dis...
# 9131  2016-12-31 11:40:00  Even on New Year's Eve, large crowds of South ...
# 9132  2016-12-31 11:20:00  Special prosecutors on Saturday formally arres...
#
#                                                    body             section  \
# 9128  Chinese airlines have withdrawn plans to run c...  Diplomatic Circuit
# 9129  South Korea's special prosecutors on Saturday ...      Social affairs
# 9130  A highly pathogenic strain of bird flu was dis...      Social affairs
# 9131  Even on New Year's Eve, large crowds of South ...      Social affairs
# 9132  Special prosecutors on Saturday formally arres...            Politics
#
#                                         summarized_body  label
# 9128  Two Chinese air carriers rolled back requests ...      0
# 9129  Moon Hyung-pyo, now chief of the National Pens...      1
# 9130  The H5N6 strain of avian influenza was found i...      2
# 9131  Hundreds of thousands were expected to partici...      3
# 9132  Moon Hyung-pyo, chief of the National Pension ...      1

# %%
df2017['label'] = event_labels_2017
df2017.head()
# Out:
# C:\Users\Modern\AppData\Local\Temp/ipykernel_20596/3055621984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2017['label'] = event_labels_2017
#                                                title         author  \
# 0      A snapshot of multiculturalism in South Korea  Lee Sun-young
# 1                   [Weekender] Korea’s dynamic 2017    Choi He-suk
# 2  People's Party members support Ahn's push for ...         Yonhap
# 3  [Newsmaker] Panamanian vessel probed over susp...         Yonhap
# 4  Hong Kong ship crew questioned in S. Korea for...            AFP
#
#                   time                                        description  \
# 0  2018-01-01 17:07:00  With birthrates persistently low and the senio...
# 1  2018-01-01 13:22:00  From North Korea’s nuclear weapons program nea...
# 2  2017-12-31 16:18:00  The leader of the center-left People's Party g...
# 3  2017-12-31 14:55:00  PYEONGTAEK  -- South Korea has seized and insp...
# 4  2017-12-30 15:44:00  The crew of a Hong Kong-registered ship have b...
#
#                                                 body         section  \
# 0  With birthrates persistently low and the senio...  Social affairs
# 1  From North Korea’s nuclear weapons program nea...  Social affairs
# 2  The leader of the center-left People's Party g...        Politics
# 3  PYEONGTAEK  -- South Korea has seized and insp...     North Korea
# 4  The crew of a Hong Kong-registered ship have b...     North Korea
#
#                                      summarized_body  label
# 0  As of 2016, more than 2 million foreign nation...      0
# 1  The corruption scandal that broke out in 2016 ...      1
# 2  Ahn Cheol-soo, leader of the center-left Peopl...      2
# 3  The 5,100-ton KOTI is being held in the wester...      3
# 4  The crew of a Hong Kong-registered ship have b...      3

# %%
# get top n most frequent labels
n = 20
label_2015 = df2015['label'].value_counts()[:n].index.tolist()
label_2016 = df2016['label'].value_counts()[:n].index.tolist()
label_2017 = df2017['label'].value_counts()[:n].index.tolist()
print(label_2015)
print(label_2016)
print(label_2017)
# Out:
# [9, 1029, 412, 125, 717, 26, 1594, 259, 946, 161, 51, 1563, 321, 1841, 74, 567, 1918, 164, 875, 531]
# [20, 12, 34, 434, 1186, 261, 380, 171, 539, 2, 674, 768, 499, 1034, 158, 1146, 507, 993, 3275, 664]
# [4, 305, 911, 219, 2850, 4258, 15, 324, 2, 1387, 1049, 3660, 391, 3593, 37, 5, 990, 1145, 215, 4278]

# %%
def freq_label(df, labels):
    freqs = []
    for label in labels:
        freq = df.loc[df.label == label, 'label'].count()
        freqs.append(freq)
    return freqs
freq_label(df2015, label_2015)
# Out:
# [598,
#  65,
#  50,
#  46,
#  40,
#  36,
#  33,
#  33,
#  28,
#  26,
#  24,
#  24,
#  22,
#  21,
#  20,
#  19,
#  18,
#  18,
#  18,
#  18]

# %%
# Concat the sentences in each group and make a summary
summary1 = []
for i in label_2015:
    s = ''
    for sentence in df2015[df2015['label'] == i]['summarized_body'].tolist():
        s += sentence
    summary1.append(s)
len(summary1)
# Out:
# 20

# %%
summary2 = []
for i in label_2016:
    s = ''
    for sentence in df2016[df2016['label'] == i]['summarized_body'].tolist():
        s += sentence
    summary2.append(s)
len(summary2)
# Out:
# 20

# %%
summary3 = []
for i in label_2017:
    s = ''
    for sentence in df2017[df2017['label'] == i]['summarized_body'].tolist():
        s += sentence
    summary3.append(s)
len(summary3)
# Out:
# 20

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn').to(device)
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')

# %%
def summarize_text(s: str):
    inputs = tokenizer([s], max_length=1024, return_tensors='pt', truncation=True).to(device)
    summary_ids = model.generate(inputs['input_ids'], num_beams=4, max_length=100, early_stopping=True)
    output = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_ids]
    torch.cuda.empty_cache()
    return output[0]

# %%
for i in range(len(summary1)):
    summary1[i] = summarize_text(summary1[i])
summary1[:5]
# Out:
# ['Seoul City will mark the New Year with a bell-tolling ceremony in the center of the capital. The military has developed the technology to diagnose Brucellosis and the Ebola virus in the early stages of infection. Facebook is the most popular social networking service in South Korea this year.',
#  'A South Korean doctor previously diagnosed with Middle East Respiratory Syndrome has been removed from an intensive care unit. The 35-year-old has tested negative for the MERS virus in two examinations. He was the only remaining patient who had not been declared free of the virus. No additional cases or fatalities have been reported since early July. Since the country reported its first MERS case on May 20, the disease has infected 186 people.',
#  'South Korea decided not to formally declare an end to the Middle East Respiratory Syndrome outbreak. The 35-year-old patient was confirmed to have been infected with the MERS virus on June 8. He was the 38th Korean to die from the viral respiratory illness since its outbreak in May, raising the nation’s MERS fatality rate to 20.4 percent.',
#  'Prime Minister Hwang Kyo-ahn announced Tuesday that South Korea would officially reinstate government-issued history textbooks for secondary education from 2017. The government plan hit a snag after a veteran history professor leading the team resigned over sexual harassment allegations.Choi Mong-lyong was invited to participate in writing the textbook. He allegedly uttered sexually offensive words and initiated inappropriate physical contact with a female reporter.',
#  "The Korean Red Cross is seeking to make video messages of about 10,000 South Koreans who's families were separated by the 1950-53 Korean War. The move is aimed at promoting exchanges among the separated families as about half of an estimated 129,700 South Koreans on the waiting list for family reunions have died. The three-day reunions for the members of 90 families, separated by. the border, ended Monday. Many of the participants, mostly in their 80s and 90"]

# %%
for i in range(len(summary2)):
    summary2[i] = summarize_text(summary2[i])
summary2[:5]
# Out:
# ['The warrant was served to 34-year-old Lim Beom-joon, who allegedly hit a passenger in the face and assaulted flight attendants. The number of flu patients from elementary, middle and high schools per 1,000 came to 152.2 from Dec. 11-17. A record high number of young patients were diagnosed with flu in the past week.',
#  'A Seoul court ruled Tuesday that a local manufacturer of humidifier disinfectants should compensate victims who died of lung disease. The case was brought against Cefu by 10 victims and the bereaved families of the dead ones in 2014. So far, 189 deaths -- mostly of lung failure -- have been formally recognized as being linked to the products.',
#  'Donald Trump is unlikely to invite North Korean leader Kim Jong-un to the US for direct talks, a US expert says. Trump first expressed his willingness to speak to Kim during a media interview in May. As the remark sparked widespread criticism, Trump doubled down on it, saying he would hold nuclear negotiations while "eating a hamburger" The painstakingly negotiated Korea-US FTA has been in effect since 2012.',
#  'A South Korean Coast Guard vessel sank when a larger Chinese vessel rear-ended it. No casualties in the incident that the Coast Guard views as an "intentional" collision. China said that an investigation is underway and it will deal with the matter in accordance with law. Seoul beefed up its response to illegal operations carried out by Chinese boats.',
#  'The main opposition The Minjoo Party of Korea announced Sunday it is uniting with the non-parliamentary Democratic Party. The integration comes ahead of next year’s presidential election. Both parties claim the foundation of the Democratic Party in 1955 against then-President Syungman Rhee as the starting point of their history.']

# %%
for i in range(len(summary3)):
    summary3[i] = summarize_text(summary3[i])
summary3[:5]
# Out:
# ['Ryugyong Kimchi Factory produces 4,200 tons of the iconic Korean pickled vegetable dish a year. Pope Francis has sent a message of encouragement to the South Korean Catholic community. South Korea has not carried out an execution since some two dozen convicts were last executed in late 2007.',
#  'Families of five missing victims of the 2014 ferry sinking held a joint funeral service on Saturday. The memorial service for the missing victims including two high school students and a teacher was held at a port in Mokpo. The first stage of the search of the ferry Sewol wrapped up Tuesday. During the 63-day search, the remains of four of nine unaccounted for passengers were identified. Three people have been identified based on the remains found since the search operations for nine people',
#  'President Park Geun-hye was impeached over a corruption scandal over the past year. The court will decide whether to permanently remove Park from office or reinstate her. The historic ruling will be announced in the main courtroom at11 a.m. and televised live nationwide. It will end a 92-day leadership crisis triggered by the Dec. 9 parliamentary impeachment.',
#  "70.8 percent of 2,517 adults surveyed said they approved of the way the president managed state affairs, down 0.7 percentage point from a week earlier. Moon's approval rating dropped for two consecutive weeks after North Korea test launched an apparent intercontinental ballistic missile on Nov. 29. Moon is set to hold a summit with his Chinese counterpart Xi Jinping on Thursday.",
#  'Chung Yoo-ra is the daughter of Choi Soon-sil, who is at the center of the corruption scandal that led to former President Park Geun-hye’s downfall. The prosecution sought an arrest warrant for Chung on Sunday on three charges -- concealing criminal proceeds, enrolling at Ewha Womans University through illegal means and using fabricated documents. Chung has denied any wrongdoing, saying that she knew nothing about what went on between her mother and Park']

# %%
# Export to csv
top20sum = pd.DataFrame(summary1, columns=[2015])
top20sum['label2015'] = label_2015
top20sum['freq2015'] = freq_label(df2015, label_2015)

top20sum[2016] = summary2
top20sum['label2016'] = label_2016
top20sum['freq2016'] = freq_label(df2016, label_2016)

top20sum[2017] = summary3
top20sum['label2017'] = label_2017
top20sum['freq2017'] = freq_label(df2017, label_2017)

# top20sum.to_csv("data/top20sum.csv", index=False)
top20sum
# Out:
#                                                  2015  label2015  freq2015  \
# 0   Seoul City will mark the New Year with a bell-...          9       598
# 1   A South Korean doctor previously diagnosed wit...       1029        65
# 2   South Korea decided not to formally declare an...        412        50
# 3   Prime Minister Hwang Kyo-ahn announced Tuesday...        125        46
# 4   The Korean Red Cross is seeking to make video ...        717        40
# 5   The main opposition New Politics Alliance for ...         26        36
# 6   The two sides plan to hold a meeting of a join...       1594        33
# 7   U.S.-China Economic and Security Review Commis...        259        33
# 8   UNESCO publishes minutes of meeting where Japa...        946        28
# 9   An estimated 2,500 gathered in the square in c...        161        26
# 10  South Korea's arms procurement agency inked Mo...         51        24
# 11  Korean Air purser Park Chang-jin lodged a suit...       1563        24
# 12  South Korea is expected to "play a more active...        321        22
# 13  Hong Joon-pyo, governor of South Gyeongsang Pr...       1841        21
# 14  119 countries voted for the resolution, while ...         74        20
# 15  Former POSCO chairman Chung Joon-yang indicted...        567        19
# 16  Rep. Won Yoo-chul was named the new floor lead...       1918        18
# 17  USFK came under fire after a joint Korea-U.S. ...        164        18
# 18  Seoul activists' leaflet launch has been one o...        875        18
# 19  South Korea’s Health Ministry plans to broadca...        531        18
#
#                                                  2016  label2016  freq2016  \
# 0   The warrant was served to 34-year-old Lim Beom...         20       739
# 1   A Seoul court ruled Tuesday that a local manuf...         12        58
# 2   Donald Trump is unlikely to invite North Korea...         34        41
# 3   A South Korean Coast Guard vessel sank when a ...        434        32
# 4   The main opposition The Minjoo Party of Korea ...       1186        31
# 5   The National Assembly is set to vote on the hi...        261        29
# 6   A 46-year-old Korean man living in Vietnam was...        380        28
# 7   President Park Geun-hye's approval rating fell...        171        28
# 8   A magnitude 3.5 earthquake has hit an area fou...        539        27
# 9   Nearly 27 million chickens and ducks at 567 fa...          2        24
# 10  North Korea is getting ready to launch yet ano...        674        22
# 11  South Korea is seeking business opportunities ...        768        21
# 12  New Seoul City Tour Bus debuted this week with...        499        18
# 13  U.S. monitoring website 38 North says construc...       1034        18
# 14  The US will soon release a second list of Nort...        158        18
# 15  U.S. research institute cites recent satellite...       1146        17
# 16  Satellite imagery of the North's Punggye-ri nu...        507        17
# 17  Seongju residents strongly protested the gover...        993        16
# 18  The final voter turnout for the parliamentary ...       3275        16
# 19  Baek Nam-gi was struck by a police water canno...        664        16
#
#                                                  2017  label2017  freq2017
# 0   Ryugyong Kimchi Factory produces 4,200 tons of...          4      1345
# 1   Families of five missing victims of the 2014 f...        305        61
# 2   President Park Geun-hye was impeached over a c...        911        60
# 3   70.8 percent of 2,517 adults surveyed said the...        219        50
# 4   Chung Yoo-ra is the daughter of Choi Soon-sil,...       2850        30
# 5   Moon Jae-in of the liberal Democratic Party ma...       4258        28
# 6   South Korea pulled the plug on the factory par...         15        27
# 7   US flew two B-1B supersonic bombers over Korea...        324        25
# 8   Ahn Cheol-soo, leader of the center-left Peopl...          2        24
# 9   South Korea has set up a task force to improve...       1387        23
# 10  Bronze statues of little girls symbolizing war...       1049        22
# 11  Ahn Cheol-soo kicks off nationwide rallies to ...       3660        22
# 12  Humane Society International has saved over 1,...        391        22
# 13  Nearly 8 in 10 eligible South Koreans voted to...       3593        20
# 14  Samsung Electronics Vice Chairman Lee Jae-yong...         37        20
# 15  Fine dust warning issued in Seoul for second t...          5        19
# 16  A majority of South Koreans support phasing ou...        990        18
# 17  Seoul, Incheon and cities in Gyeonggi Province...       1145        17
# 18  The accident occurred at 7:59 a.m. at Onsu Sta...        215        17
# 19  Malaysia agreed to send to North Korea the bod...       4278        16

# %%
top20sum.to_csv("data/top20sum_eps04.csv", index=False)

# %%
# Original data with label
# df2015.to_csv("data/df2015.csv", index=False)
# df2016.to_csv("data/df2016.csv", index=False)
# df2017.to_csv("data/df2017.csv", index=False)
